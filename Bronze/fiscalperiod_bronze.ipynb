# %% [markdown]
# ###Run Shared Libraries

# %%
# %run ../Misc/sharedlibraries

# %% [markdown]
# ###Set Variables

# %%
Entity = "FiscalPeriod"
EntityPath = f"Others/{Entity}/"

# %% [markdown]
# ###Read From Delta Raw Path

# %%
entitydf = readFromDeltaPath(EntityPath)
display(entitydf)

# %% [markdown]
# ###Verify Entity Schema

# %%
entitydf.printSchema()

# %% [markdown]
# ###Save to Bronze schema

# %%
saveDeltaTableToCatalog(entitydf,"Bronze",Entity)

# %% [markdown]
# ###Validate Bronze Table

# %%
display(spark.table("bronze.FiscalPeriod"))
